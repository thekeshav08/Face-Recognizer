# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
# !pip install --upgrade bottleneck
# Out:
# Requirement already satisfied: bottleneck in c:\users\theke\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy in c:\users\theke\anaconda3\lib\site-packages (from bottleneck) (1.23.5)

# %%
from keras.models import Sequential, Model
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D, AveragePooling2D, Concatenate
from keras.layers import Lambda, Flatten, Dense
from keras import backend as K
import cv2
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from utils import LRN2D  # Ensure this is correctly installed or accessible
import utils

# Reload modules for development convenience
# %reload_ext autoreload
# %autoreload 2

# Set print options
import sys
np.set_printoptions(threshold=sys.maxsize)

# Ensure your libraries are up to date:
# pip install --upgrade keras tensorflow pandas bottleneck

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: tf.sqrt(x), 
                           name='sqrt_3b',
                           output_shape=lambda input_shape: input_shape)(inception_3b_pool)

inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: tf.sqrt(x),
                           name='sqrt_4a',
                           output_shape=lambda input_shape: input_shape)(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(
    lambda x: tf.sqrt(x),
    name='sqrt_5a',
    output_shape=lambda input_shape: input_shape
)(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(
    lambda x: tf.linalg.l2_normalize(x, axis=1),  # Use tf.linalg.l2_normalize instead of K.l2_normalize
    name='norm_layer',
    output_shape=lambda input_shape: input_shape
)(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)
# Out:
# C:\Users\theke\anaconda3\Lib\site-packages\keras\src\layers\reshaping\zero_padding2d.py:72: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:From C:\Users\theke\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 0.68:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Capturing the face image
# Following code captures 10 face images of the person. They all are stored in **"images"** folder with the name User_1 to User_10. Select a good captured image from the set of 10 images. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
cam = cv2.VideoCapture(0)

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
while(True):
    ret, img = cam.read()
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Save the captured image into the datasets folder
        cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= 10: # Take 30 face sample and stop video
         break
cam.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Lets run the face recognizer program :-)

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from Keshav is 0.53551245
# Euclidean distance from Mansi is 0.32879725
# Euclidean distance from openface is 1.1465355
# Euclidean distance from output1 is 1.5535883
# Euclidean distance from Keshav is 0.6226486
# Euclidean distance from Mansi is 0.8871038
# Euclidean distance from openface is 0.95056015
# Euclidean distance from output1 is 1.4619712
# Euclidean distance from Keshav is 0.5975191
# Euclidean distance from Mansi is 0.28818196
# Euclidean distance from openface is 1.1851252
# Euclidean distance from output1 is 1.5728118
# Euclidean distance from Keshav is 0.5181271
# Euclidean distance from Mansi is 0.7548531
# Euclidean distance from openface is 0.9358602
# Euclidean distance from output1 is 1.5043478
# Euclidean distance from Keshav is 0.5337233
# Euclidean distance from Mansi is 0.41448668
# Euclidean distance from openface is 1.108706
# Euclidean distance from output1 is 1.5360351
# Euclidean distance from Keshav is 0.624334
# Euclidean distance from Mansi is 0.8330583
# Euclidean distance from openface is 0.9507004
# Euclidean distance from output1 is 1.4809992
# Euclidean distance from Keshav is 1.5411553
# Euclidean distance from Mansi is 1.555286
# Euclidean distance from openface is 1.3467964
# Euclidean distance from output1 is 1.0030588
# Euclidean distance from Keshav is 0.7151302
# Euclidean distance from Mansi is 0.9453275
# Euclidean distance from openface is 0.9886957
# Euclidean distance from output1 is 1.4708041
# Euclidean distance from Keshav is 0.5346638
# Euclidean distance from Mansi is 0.35503688
# Euclidean distance from openface is 1.153938
# Euclidean distance from output1 is 1.5477855
# Euclidean distance from Keshav is 1.4155393
# Euclidean distance from Mansi is 1.4654171
# Euclidean distance from openface is 1.2034543
# Euclidean distance from output1 is 0.98760676
# Euclidean distance from Keshav is 0.62125677
# Euclidean distance from Mansi is 0.8989438
# Euclidean distance from openface is 0.83556795
# Euclidean distance from output1 is 1.45489
# Euclidean distance from Keshav is 0.6485035
# Euclidean distance from Mansi is 0.28851837
# Euclidean distance from openface is 1.1870105
# Euclidean distance from output1 is 1.5772177
# Euclidean distance from Keshav is 0.6272521
# Euclidean distance from Mansi is 0.30295768
# Euclidean distance from openface is 1.1416445
# Euclidean distance from output1 is 1.5601463
# Euclidean distance from Keshav is 0.46996275
# Euclidean distance from Mansi is 0.7400967
# Euclidean distance from openface is 0.8837753
# Euclidean distance from output1 is 1.5191538
# Euclidean distance from Keshav is 0.6396735
# Euclidean distance from Mansi is 0.27215403
# Euclidean distance from openface is 1.1944398
# Euclidean distance from output1 is 1.5644969
# Euclidean distance from Keshav is 0.5377366
# Euclidean distance from Mansi is 0.79873866
# Euclidean distance from openface is 0.87233645
# Euclidean distance from output1 is 1.4909282
# Euclidean distance from Keshav is 0.64005893
# Euclidean distance from Mansi is 0.28866816
# Euclidean distance from openface is 1.2267852
# Euclidean distance from output1 is 1.5601158
# Euclidean distance from Keshav is 0.5463877
# Euclidean distance from Mansi is 0.81702816
# Euclidean distance from openface is 0.8747304
# Euclidean distance from output1 is 1.4620821
# Euclidean distance from Keshav is 0.5270594
# Euclidean distance from Mansi is 0.8112124
# Euclidean distance from openface is 0.8732052
# Euclidean distance from output1 is 1.4855746
# Euclidean distance from Keshav is 0.6699534
# Euclidean distance from Mansi is 0.27257854
# Euclidean distance from openface is 1.214433
# Euclidean distance from output1 is 1.5762088
# Euclidean distance from Keshav is 0.66668344
# Euclidean distance from Mansi is 0.25736132
# Euclidean distance from openface is 1.2162111
# Euclidean distance from output1 is 1.5707675
# Euclidean distance from Keshav is 0.54047704
# Euclidean distance from Mansi is 0.8364848
# Euclidean distance from openface is 0.82689905
# Euclidean distance from output1 is 1.4778634
# Euclidean distance from Keshav is 0.6393868
# Euclidean distance from Mansi is 0.9249476
# Euclidean distance from openface is 0.8596444
# Euclidean distance from output1 is 1.4450864
# Euclidean distance from Keshav is 0.60903615
# Euclidean distance from Mansi is 0.281393
# Euclidean distance from openface is 1.1739969
# Euclidean distance from output1 is 1.5411942
# Euclidean distance from Keshav is 1.5130831
# Euclidean distance from Mansi is 1.5425459
# Euclidean distance from openface is 1.2342657
# Euclidean distance from output1 is 1.1397197
# Euclidean distance from Keshav is 0.589099
# Euclidean distance from Mansi is 0.87041986
# Euclidean distance from openface is 0.86106825
# Euclidean distance from output1 is 1.472658
# Euclidean distance from Keshav is 0.586501
# Euclidean distance from Mansi is 0.26046905
# Euclidean distance from openface is 1.1681243
# Euclidean distance from output1 is 1.5586952
# Euclidean distance from Keshav is 0.5716558
# Euclidean distance from Mansi is 0.87846386
# Euclidean distance from openface is 0.89528686
# Euclidean distance from output1 is 1.4636106
# Euclidean distance from Keshav is 0.5254257
# Euclidean distance from Mansi is 0.29996517
# Euclidean distance from openface is 1.118704
# Euclidean distance from output1 is 1.5427048
# Euclidean distance from Keshav is 0.5523853
# Euclidean distance from Mansi is 0.31205502
# Euclidean distance from openface is 1.1724788
# Euclidean distance from output1 is 1.5525162
# Euclidean distance from Keshav is 0.6099888
# Euclidean distance from Mansi is 0.87458533
# Euclidean distance from openface is 0.9283744
# Euclidean distance from output1 is 1.4725018
# Euclidean distance from Keshav is 0.4893392
# Euclidean distance from Mansi is 0.7931938
# Euclidean distance from openface is 0.90857387
# Euclidean distance from output1 is 1.5013057
# Euclidean distance from Keshav is 0.61429346
# Euclidean distance from Mansi is 0.27616304
# Euclidean distance from openface is 1.1877736
# Euclidean distance from output1 is 1.5879846
# Euclidean distance from Keshav is 0.5872638
# Euclidean distance from Mansi is 0.26522374
# Euclidean distance from openface is 1.1605725
# Euclidean distance from output1 is 1.5519302
# Euclidean distance from Keshav is 0.5913286
# Euclidean distance from Mansi is 0.8824736
# Euclidean distance from openface is 0.8877477
# Euclidean distance from output1 is 1.4715104
# Euclidean distance from Keshav is 1.3856775
# Euclidean distance from Mansi is 1.4153401
# Euclidean distance from openface is 1.1769142
# Euclidean distance from output1 is 1.196847
# Euclidean distance from Keshav is 0.56724817
# Euclidean distance from Mansi is 0.8462845
# Euclidean distance from openface is 0.976439
# Euclidean distance from output1 is 1.5039619
# Euclidean distance from Keshav is 0.6061213
# Euclidean distance from Mansi is 0.28231585
# Euclidean distance from openface is 1.2107279
# Euclidean distance from output1 is 1.556066
# Euclidean distance from Keshav is 1.4200525
# Euclidean distance from Mansi is 1.4379668
# Euclidean distance from openface is 1.1528858
# Euclidean distance from output1 is 1.1693797
# Euclidean distance from Keshav is 0.6486704
# Euclidean distance from Mansi is 0.29747006
# Euclidean distance from openface is 1.1827545
# Euclidean distance from output1 is 1.5701195
# Euclidean distance from Keshav is 0.53668743
# Euclidean distance from Mansi is 0.83368367
# Euclidean distance from openface is 0.9238968
# Euclidean distance from output1 is 1.4903796
# Euclidean distance from Keshav is 0.6335872
# Euclidean distance from Mansi is 0.39556527
# Euclidean distance from openface is 1.1283727
# Euclidean distance from output1 is 1.5681599
# Euclidean distance from Keshav is 1.3969252
# Euclidean distance from Mansi is 1.4362619
# Euclidean distance from openface is 1.1926154
# Euclidean distance from output1 is 1.2058213
# Euclidean distance from Keshav is 0.6016824
# Euclidean distance from Mansi is 0.89310163
# Euclidean distance from openface is 0.89585847
# Euclidean distance from output1 is 1.46114
# Euclidean distance from Keshav is 1.4726702
# Euclidean distance from Mansi is 1.5035324
# Euclidean distance from openface is 1.2270435
# Euclidean distance from output1 is 1.082839
# Euclidean distance from Keshav is 0.53228885
# Euclidean distance from Mansi is 0.8091485
# Euclidean distance from openface is 0.93894553
# Euclidean distance from output1 is 1.5073445
# Euclidean distance from Keshav is 0.5955532
# Euclidean distance from Mansi is 0.30054277
# Euclidean distance from openface is 1.1830573
# Euclidean distance from output1 is 1.563524
# Euclidean distance from Keshav is 0.5956369
# Euclidean distance from Mansi is 0.29420227
# Euclidean distance from openface is 1.1960952
# Euclidean distance from output1 is 1.5558865
# Euclidean distance from Keshav is 0.6003804
# Euclidean distance from Mansi is 0.8574236
# Euclidean distance from openface is 0.96873486
# Euclidean distance from output1 is 1.493375
# Euclidean distance from Keshav is 0.5376796
# Euclidean distance from Mansi is 0.3375551
# Euclidean distance from openface is 1.144593
# Euclidean distance from output1 is 1.5747563
# Euclidean distance from Keshav is 0.5469787
# Euclidean distance from Mansi is 0.84907705
# Euclidean distance from openface is 0.9316891
# Euclidean distance from output1 is 1.4906673
# Euclidean distance from Keshav is 0.5362493
# Euclidean distance from Mansi is 0.8487545
# Euclidean distance from openface is 0.934539
# Euclidean distance from output1 is 1.4781816
# Euclidean distance from Keshav is 0.6105172
# Euclidean distance from Mansi is 0.3011782
# Euclidean distance from openface is 1.1847601
# Euclidean distance from output1 is 1.5838608
# Euclidean distance from Keshav is 0.51630074
# Euclidean distance from Mansi is 0.8156819
# Euclidean distance from openface is 0.94719785
# Euclidean distance from output1 is 1.5011387
# Euclidean distance from Keshav is 0.603428
# Euclidean distance from Mansi is 0.33069906
# Euclidean distance from openface is 1.197254
# Euclidean distance from output1 is 1.5677184
# Euclidean distance from Keshav is 0.5764289
# Euclidean distance from Mansi is 0.34004688
# Euclidean distance from openface is 1.1892148
# Euclidean distance from output1 is 1.5883933
# Euclidean distance from Keshav is 0.532153
# Euclidean distance from Mansi is 0.81304514
# Euclidean distance from openface is 0.93214875
# Euclidean distance from output1 is 1.4527073
# Euclidean distance from Keshav is 0.5406938
# Euclidean distance from Mansi is 0.8022105
# Euclidean distance from openface is 1.0130144
# Euclidean distance from output1 is 1.5137049
# Euclidean distance from Keshav is 0.5643957
# Euclidean distance from Mansi is 0.38560912
# Euclidean distance from openface is 1.193408
# Euclidean distance from output1 is 1.5774242
# Euclidean distance from Keshav is 0.5418938
# Euclidean distance from Mansi is 0.8234552
# Euclidean distance from openface is 0.9199794
# Euclidean distance from output1 is 1.507756
# Euclidean distance from Keshav is 0.5677321
# Euclidean distance from Mansi is 0.37109628
# Euclidean distance from openface is 1.1556151
# Euclidean distance from output1 is 1.550507
# Euclidean distance from Keshav is 0.5181732
# Euclidean distance from Mansi is 0.8040167
# Euclidean distance from openface is 0.93133456
# Euclidean distance from output1 is 1.5211945
# Euclidean distance from Keshav is 0.5822326
# Euclidean distance from Mansi is 0.3201257
# Euclidean distance from openface is 1.1711997
# Euclidean distance from output1 is 1.5637975
# Euclidean distance from Keshav is 0.47098383
# Euclidean distance from Mansi is 0.713144
# Euclidean distance from openface is 1.0010853
# Euclidean distance from output1 is 1.5398415
# Euclidean distance from Keshav is 0.5506699
# Euclidean distance from Mansi is 0.3141589
# Euclidean distance from openface is 1.1630431
# Euclidean distance from output1 is 1.5651122
# Euclidean distance from Keshav is 0.5761952
# Euclidean distance from Mansi is 0.2955617
# Euclidean distance from openface is 1.1936166
# Euclidean distance from output1 is 1.5660725
# Euclidean distance from Keshav is 1.374312
# Euclidean distance from Mansi is 1.403653
# Euclidean distance from openface is 1.1184748
# Euclidean distance from output1 is 1.3009295
# Euclidean distance from Keshav is 0.5681587
# Euclidean distance from Mansi is 0.84701407
# Euclidean distance from openface is 0.9443067
# Euclidean distance from output1 is 1.4815029
# Euclidean distance from Keshav is 0.59910005
# Euclidean distance from Mansi is 0.30801532
# Euclidean distance from openface is 1.197941
# Euclidean distance from output1 is 1.5547835
# Euclidean distance from Keshav is 0.5228003
# Euclidean distance from Mansi is 0.79377425
# Euclidean distance from openface is 0.9687513
# Euclidean distance from output1 is 1.5033755
# Euclidean distance from Keshav is 0.5567994
# Euclidean distance from Mansi is 0.3471557
# Euclidean distance from openface is 1.1604502
# Euclidean distance from output1 is 1.573632
# Euclidean distance from Keshav is 0.5639955
# Euclidean distance from Mansi is 0.84858924
# Euclidean distance from openface is 0.8945795
# Euclidean distance from output1 is 1.4999996
# Euclidean distance from Keshav is 1.565202
# Euclidean distance from Mansi is 1.5896502
# Euclidean distance from openface is 1.317178
# Euclidean distance from output1 is 0.8885657
# Euclidean distance from Keshav is 0.554937
# Euclidean distance from Mansi is 0.8440668
# Euclidean distance from openface is 0.9355318
# Euclidean distance from output1 is 1.4890791
# Euclidean distance from Keshav is 0.580867
# Euclidean distance from Mansi is 0.33823183
# Euclidean distance from openface is 1.186554
# Euclidean distance from output1 is 1.5554864
# Euclidean distance from Keshav is 0.507937
# Euclidean distance from Mansi is 0.81419945
# Euclidean distance from openface is 0.9248206
# Euclidean distance from output1 is 1.4942482
# Euclidean distance from Keshav is 0.52103424
# Euclidean distance from Mansi is 0.33246553
# Euclidean distance from openface is 1.1330289
# Euclidean distance from output1 is 1.5348934
# Euclidean distance from Keshav is 0.517119
# Euclidean distance from Mansi is 0.79680926
# Euclidean distance from openface is 0.93663776
# Euclidean distance from output1 is 1.5055243
# Euclidean distance from Keshav is 0.5453999
# Euclidean distance from Mansi is 0.36450413
# Euclidean distance from openface is 1.1564697
# Euclidean distance from output1 is 1.5354329
# Euclidean distance from Keshav is 1.2532606
# Euclidean distance from Mansi is 1.2499902
# Euclidean distance from openface is 1.131238
# Euclidean distance from output1 is 1.2848701
# Euclidean distance from Keshav is 0.46365148
# Euclidean distance from Mansi is 0.7477084
# Euclidean distance from openface is 0.9648523
# Euclidean distance from output1 is 1.5307869
# Euclidean distance from Keshav is 0.5626687
# Euclidean distance from Mansi is 0.3052351
# Euclidean distance from openface is 1.1453366
# Euclidean distance from output1 is 1.5423766
# Euclidean distance from Keshav is 0.57694787
# Euclidean distance from Mansi is 0.30523792
# Euclidean distance from openface is 1.1895406
# Euclidean distance from output1 is 1.5529823
# Euclidean distance from Keshav is 1.5046117
# Euclidean distance from Mansi is 1.5076208
# Euclidean distance from openface is 1.1869531
# Euclidean distance from output1 is 1.1165209
# Euclidean distance from Keshav is 0.58763415
# Euclidean distance from Mansi is 0.86688644
# Euclidean distance from openface is 0.9153975
# Euclidean distance from output1 is 1.4882265
# Euclidean distance from Keshav is 0.49725866
# Euclidean distance from Mansi is 0.8010017
# Euclidean distance from openface is 0.9612868
# Euclidean distance from output1 is 1.5031471
# Euclidean distance from Keshav is 0.6187661
# Euclidean distance from Mansi is 0.29487798
# Euclidean distance from openface is 1.1997714
# Euclidean distance from output1 is 1.5619013
# Euclidean distance from Keshav is 1.2631433
# Euclidean distance from Mansi is 1.2889291
# Euclidean distance from openface is 1.0965595
# Euclidean distance from output1 is 1.3300133
# Euclidean distance from Keshav is 0.5229055
# Euclidean distance from Mansi is 0.7980548
# Euclidean distance from openface is 0.97754383
# Euclidean distance from output1 is 1.5338936
# Euclidean distance from Keshav is 0.58488804
# Euclidean distance from Mansi is 0.3246643
# Euclidean distance from openface is 1.1721048
# Euclidean distance from output1 is 1.5541815
# Euclidean distance from Keshav is 0.51817364
# Euclidean distance from Mansi is 0.7982124
# Euclidean distance from openface is 0.94120395
# Euclidean distance from output1 is 1.5195669
# Euclidean distance from Keshav is 0.5840679
# Euclidean distance from Mansi is 0.31949598
# Euclidean distance from openface is 1.1800907
# Euclidean distance from output1 is 1.5461043
# Euclidean distance from Keshav is 0.4856069
# Euclidean distance from Mansi is 0.80401903
# Euclidean distance from openface is 0.9242557
# Euclidean distance from output1 is 1.5208278
# Euclidean distance from Keshav is 0.59160346
# Euclidean distance from Mansi is 0.34252933
# Euclidean distance from openface is 1.1679059
# Euclidean distance from output1 is 1.5468642
# Euclidean distance from Keshav is 0.5711266
# Euclidean distance from Mansi is 0.3162406
# Euclidean distance from openface is 1.1456017
# Euclidean distance from output1 is 1.5671452
# Euclidean distance from Keshav is 0.46815935
# Euclidean distance from Mansi is 0.7720814
# Euclidean distance from openface is 0.90886974
# Euclidean distance from output1 is 1.4842423
# Euclidean distance from Keshav is 1.5568322
# Euclidean distance from Mansi is 1.5542051
# Euclidean distance from openface is 1.2854817
# Euclidean distance from output1 is 0.8779749
# Euclidean distance from Keshav is 0.58744735
# Euclidean distance from Mansi is 0.34523955
# Euclidean distance from openface is 1.1936145
# Euclidean distance from output1 is 1.5450565
# Euclidean distance from Keshav is 0.46550012
# Euclidean distance from Mansi is 0.71797794
# Euclidean distance from openface is 0.9524542
# Euclidean distance from output1 is 1.5368755
# Euclidean distance from Keshav is 0.58731484
# Euclidean distance from Mansi is 0.34896505
# Euclidean distance from openface is 1.1802084
# Euclidean distance from output1 is 1.5632327
# Euclidean distance from Keshav is 0.5161953
# Euclidean distance from Mansi is 0.7871364
# Euclidean distance from openface is 0.93882763
# Euclidean distance from output1 is 1.4734793
# Euclidean distance from Keshav is 0.5211491
# Euclidean distance from Mansi is 0.83703494
# Euclidean distance from openface is 0.9430662
# Euclidean distance from output1 is 1.4798967
# Euclidean distance from Keshav is 0.5544398
# Euclidean distance from Mansi is 0.32483816
# Euclidean distance from openface is 1.175554
# Euclidean distance from output1 is 1.556913
# Euclidean distance from Keshav is 0.54013103
# Euclidean distance from Mansi is 0.31784624
# Euclidean distance from openface is 1.1462644
# Euclidean distance from output1 is 1.5564758
# Euclidean distance from Keshav is 0.5366278
# Euclidean distance from Mansi is 0.8157134
# Euclidean distance from openface is 0.9381544
# Euclidean distance from output1 is 1.5318036
# Euclidean distance from Keshav is 0.494063
# Euclidean distance from Mansi is 0.7577341
# Euclidean distance from openface is 0.9741863
# Euclidean distance from output1 is 1.5408058
# Euclidean distance from Keshav is 0.53404504
# Euclidean distance from Mansi is 0.34495148
# Euclidean distance from openface is 1.1322118
# Euclidean distance from output1 is 1.5458481
# Euclidean distance from Keshav is 0.53329504
# Euclidean distance from Mansi is 0.38009146
# Euclidean distance from openface is 1.1420666
# Euclidean distance from output1 is 1.5621581
# Euclidean distance from Keshav is 0.4512168
# Euclidean distance from Mansi is 0.67984027
# Euclidean distance from openface is 1.0067337
# Euclidean distance from output1 is 1.5609174
# Euclidean distance from Keshav is 0.4940836
# Euclidean distance from Mansi is 0.7893126
# Euclidean distance from openface is 0.9644801
# Euclidean distance from output1 is 1.5211755
# Euclidean distance from Keshav is 0.5003907
# Euclidean distance from Mansi is 0.4273122
# Euclidean distance from openface is 1.1231427
# Euclidean distance from output1 is 1.546676
# Euclidean distance from Keshav is 0.43792942
# Euclidean distance from Mansi is 0.71844375
# Euclidean distance from openface is 1.0035349
# Euclidean distance from output1 is 1.533478
# Euclidean distance from Keshav is 0.6135642
# Euclidean distance from Mansi is 0.24417451
# Euclidean distance from openface is 1.1597489
# Euclidean distance from output1 is 1.5586857
# Euclidean distance from Keshav is 1.5792929
# Euclidean distance from Mansi is 1.5684192
# Euclidean distance from openface is 1.43822
# Euclidean distance from output1 is 1.0052732
# Euclidean distance from Keshav is 0.45556152
# Euclidean distance from Mansi is 0.7873865
# Euclidean distance from openface is 0.9729438
# Euclidean distance from output1 is 1.5339674
# Euclidean distance from Keshav is 0.700896
# Euclidean distance from Mansi is 0.29852462
# Euclidean distance from openface is 1.181765
# Euclidean distance from output1 is 1.5529583
# Euclidean distance from Keshav is 0.585328
# Euclidean distance from Mansi is 0.9461085
# Euclidean distance from openface is 0.89866513
# Euclidean distance from output1 is 1.525358
# Euclidean distance from Keshav is 0.56756973
# Euclidean distance from Mansi is 0.4593759
# Euclidean distance from openface is 0.9587822
# Euclidean distance from output1 is 1.5719196
# Euclidean distance from Keshav is 1.5227381
# Euclidean distance from Mansi is 1.5549247
# Euclidean distance from openface is 1.2155708
# Euclidean distance from output1 is 1.0455782
# Euclidean distance from Keshav is 0.5954623
# Euclidean distance from Mansi is 0.93358123
# Euclidean distance from openface is 0.92221725
# Euclidean distance from output1 is 1.5495439
# Euclidean distance from Keshav is 0.7313454
# Euclidean distance from Mansi is 1.0490929
# Euclidean distance from openface is 0.92684567
# Euclidean distance from output1 is 1.4950172
# Euclidean distance from Keshav is 0.71935385
# Euclidean distance from Mansi is 1.0586119
# Euclidean distance from openface is 0.91518635
# Euclidean distance from output1 is 1.5014443
# Euclidean distance from Keshav is 0.73360616
# Euclidean distance from Mansi is 1.0781196
# Euclidean distance from openface is 0.94190377
# Euclidean distance from output1 is 1.5117714
# Euclidean distance from Keshav is 0.60430145
# Euclidean distance from Mansi is 0.98253953
# Euclidean distance from openface is 0.9357795
# Euclidean distance from output1 is 1.5555701
# Euclidean distance from Keshav is 0.6243406
# Euclidean distance from Mansi is 1.0021675
# Euclidean distance from openface is 0.91660416
# Euclidean distance from output1 is 1.5283957
# Euclidean distance from Keshav is 0.59816325
# Euclidean distance from Mansi is 0.9733653
# Euclidean distance from openface is 0.9399491
# Euclidean distance from output1 is 1.5442383
# Euclidean distance from Keshav is 0.6181772
# Euclidean distance from Mansi is 1.0050751
# Euclidean distance from openface is 0.9202905
# Euclidean distance from output1 is 1.5380689
# Euclidean distance from Keshav is 0.570765
# Euclidean distance from Mansi is 0.9528035
# Euclidean distance from openface is 0.9437475
# Euclidean distance from output1 is 1.5274649
# Euclidean distance from Keshav is 0.56637895
# Euclidean distance from Mansi is 0.937433
# Euclidean distance from openface is 0.9406868
# Euclidean distance from output1 is 1.5148627
# Euclidean distance from Keshav is 0.5835638
# Euclidean distance from Mansi is 0.95538837
# Euclidean distance from openface is 0.9522928
# Euclidean distance from output1 is 1.5411824
# Euclidean distance from Keshav is 0.55692834
# Euclidean distance from Mansi is 0.91070396
# Euclidean distance from openface is 0.96392924
# Euclidean distance from output1 is 1.5483984
# Euclidean distance from Keshav is 0.74900484
# Euclidean distance from Mansi is 1.0588806
# Euclidean distance from openface is 0.95993584
# Euclidean distance from output1 is 1.4461977
# Euclidean distance from Keshav is 0.7568122
# Euclidean distance from Mansi is 1.0947679
# Euclidean distance from openface is 0.92453456
# Euclidean distance from output1 is 1.4379982
# Euclidean distance from Keshav is 0.80872583
# Euclidean distance from Mansi is 1.1458819
# Euclidean distance from openface is 0.8882902
# Euclidean distance from output1 is 1.4772291
# Euclidean distance from Keshav is 1.4270525
# Euclidean distance from Mansi is 1.4823921
# Euclidean distance from openface is 1.0814408
# Euclidean distance from output1 is 1.0755383
# Euclidean distance from Keshav is 0.7694072
# Euclidean distance from Mansi is 1.1059235
# Euclidean distance from openface is 0.93711126
# Euclidean distance from output1 is 1.4692414
# Euclidean distance from Keshav is 0.79184586
# Euclidean distance from Mansi is 1.1062053
# Euclidean distance from openface is 0.9304666
# Euclidean distance from output1 is 1.4867485
# Euclidean distance from Keshav is 0.7283631
# Euclidean distance from Mansi is 1.0558771
# Euclidean distance from openface is 0.9166153
# Euclidean distance from output1 is 1.4842753
# Euclidean distance from Keshav is 0.7954402
# Euclidean distance from Mansi is 1.1032745
# Euclidean distance from openface is 0.9309827
# Euclidean distance from output1 is 1.4324858
# Euclidean distance from Keshav is 0.8245927
# Euclidean distance from Mansi is 1.1395701
# Euclidean distance from openface is 0.96548617
# Euclidean distance from output1 is 1.4507997
# Euclidean distance from Keshav is 1.500713
# Euclidean distance from Mansi is 1.5202525
# Euclidean distance from openface is 1.1828486
# Euclidean distance from output1 is 1.1440957
# Euclidean distance from Keshav is 0.5964126
# Euclidean distance from Mansi is 0.9569175
# Euclidean distance from openface is 0.95388645
# Euclidean distance from output1 is 1.5242064
# Euclidean distance from Keshav is 0.5901359
# Euclidean distance from Mansi is 0.98596996
# Euclidean distance from openface is 0.9208166
# Euclidean distance from output1 is 1.5032967
# Euclidean distance from Keshav is 0.5926599
# Euclidean distance from Mansi is 0.9082859
# Euclidean distance from openface is 0.9725316
# Euclidean distance from output1 is 1.4794121
